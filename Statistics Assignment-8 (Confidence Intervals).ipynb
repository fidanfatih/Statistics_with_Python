# %% [markdown]
# #### EXERCISE 1.
# Suppose scores on exams in statistics are normally distributed with an unknown population mean and a population standard deviation of 3 points. A random sample of 36 scores is taken and gives a sample mean (sample  mean score) of 68. Find a confidence interval estimate for the population mean exam score (the mean score on all exams).
# Find a 90% confidence interval for the true (population) mean of statistics exam scores.

# %%
import random
from math import sqrt
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
random.seed(101)

# %%
# normal distribution
# mu is unknown
sigma=3
n=36
x=68
CI=0.9

# %%
s=sigma/sqrt(n)
stats.norm.interval(CI, loc= x, scale= s)
# Out:
# (67.17757318652427, 68.82242681347573)

# %%
# or
z=stats.norm.ppf((1-CI)/2+CI)
lower_limit= x - z*s
upper_limit= x + z*s

lower_limit, upper_limit
# Out:
# (67.17757318652427, 68.82242681347573)

# %% [markdown]
# #### EXERCISE 2.
# What is the normal body temperature for healthy humans? A random sample of 130 healthy human body temperatures provided by Allen Shoemaker7 yielded 98.25 degrees(Fahrenheit) and standard deviation 0.73 degrees.
# Give a 99% confidence interval for the average body temperature of healthy people.

# %%
# normal distribution
s=0.73
n=130
x=98.25
CI=0.99

# %%
stats.norm.interval(CI, loc= x, scale= s)
# Out:
# (96.3696446084093, 100.1303553915907)

# %%
#or
z=stats.norm.ppf((1-CI)/2+CI)
lower_limit= x - z*s
upper_limit= x + z*s

lower_limit, upper_limit
# Out:
# (96.3696446084093, 100.1303553915907)

# %% [markdown]
# #### EXERCISE 3.
# The administrators for a hospital wished to estimate the average number of days required for inpatient treatment of patients between the ages of 25 and 34. A random sample of 500 hospital patients between these ages produced a mean and standard deviation equal to 5.4 and 3.1 days, respectively.
# Construct a 95% confidence interval for the mean length of stay for the population of patients from which the sample was drawn.

# %%
# sigma is unknown, so we use t distrinution
n= 500
x= 5.4
s= 3.1
CI=0.95
df=n-1

# %% [markdown]
# ![Ads%C4%B1z.png](attachment:Ads%C4%B1z.png)

# %%
sm=s/sqrt(n) # Standard Error of Sample:
t=stats.t.interval(CI, df)[1]
[ x-t*sm, x+t*sm]
# Out:
# [5.109831068019656, 5.690168931980344]
